# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix

# %%
mnist=fetch_openml('mnist_784')
x=mnist['data']
y=mnist['target']
x=x/255

# %%
x_train,x_test ,y_train ,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
log_reg=LogisticRegression( max_iter=1000 , solver='lbfgs',multi_class='multinomial')
log_reg.fit(x_train ,y_train)
y_pred=log_reg.predict(x_test)
# Out:
# /home/versus/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
accuracy=accuracy_score(y_pred,y_test)
classification=classification_report(y_pred,y_test)
confusion=confusion_matrix(y_pred,y_test)

# %%
n_images=10
indices = np.random.choice(len(x_test),n_images)
for i in indices:
    plt.imshow(x_test.iloc[i].values.reshape(28,28),cmap='gray')
    plt.title(f'Predicted Value: {y_pred[i]}')
    plt.show()

print(classification)
print(accuracy)
print(confusion)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1347
#            1       0.97      0.94      0.96      1639
#            2       0.89      0.91      0.90      1349
#            3       0.89      0.90      0.90      1420
#            4       0.93      0.92      0.92      1306
#            5       0.88      0.88      0.88      1271
#            6       0.95      0.94      0.95      1411
#            7       0.94      0.93      0.94      1527
#            8       0.87      0.90      0.88      1312
#            9       0.90      0.90      0.90      1418
#
#     accuracy                           0.92     14000
#    macro avg       0.92      0.92      0.92     14000
# weighted avg       0.92      0.92      0.92     14000
#
# 0.9204285714285714
# [[1298    0    5    6    6    4    5    6   10    7]
#  [   1 1548   20    9    3   11    5    4   27   11]
#  [   6    6 1232   30    6    7   19   25   13    5]
#  [   0   10   21 1282    4   42    1    3   44   13]
#  [   4    3   16    1 1202   12   14   10    6   38]
#  [  11   12   10   39    5 1121   17    6   43    7]
#  [  11    0   20    7   10   23 1331    0    9    0]
#  [   4    4   17   18    8    4    1 1417    9   45]
#  [   6   15   29   23    7   35    3    1 1177   16]
#  [   2    2   10   18   44   14    0   31   19 1278]]
